# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
daily_data = pd.read_csv('../Data/daily.csv', index_col=0)

# %%
daily_data
# Out:
#              dteday  season  yr  mnth  holiday  weekday  workingday  \
# instant
# 1        2011-01-01       1   0     1        0        6           0
# 2        2011-01-02       1   0     1        0        0           0
# 3        2011-01-03       1   0     1        0        1           1
# 4        2011-01-04       1   0     1        0        2           1
# 5        2011-01-05       1   0     1        0        3           1
# ...             ...     ...  ..   ...      ...      ...         ...
# 727      2012-12-27       1   1    12        0        4           1
# 728      2012-12-28       1   1    12        0        5           1
# 729      2012-12-29       1   1    12        0        6           0
# 730      2012-12-30       1   1    12        0        0           0
# 731      2012-12-31       1   1    12        0        1           1
#
#          weathersit      temp     atemp       hum  windspeed  casual  \
# instant
# ...

# %%
daily_X = daily_data.drop(columns=['cnt', 'casual', 'registered'])
daily_y = daily_data.cnt

# %%
daily_X.corrwith(daily_y)
# Out:
# season        0.406100
# yr            0.566710
# mnth          0.279977
# holiday      -0.068348
# weekday       0.067443
# workingday    0.061156
# weathersit   -0.297391
# temp          0.627494
# atemp         0.631066
# hum          -0.100659
# windspeed    -0.234545
# dtype: float64

# %%
daily_X.corrwith(daily_y).abs().plot.bar()
plt.show()

# %%
hourly_data = pd.read_csv('../Data/hourly.csv', index_col=0)

# %%
hourly_data
# Out:
#              dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# instant
# 1        2011-01-01       1   0     1   0        0        6           0
# 2        2011-01-01       1   0     1   1        0        6           0
# 3        2011-01-01       1   0     1   2        0        6           0
# 4        2011-01-01       1   0     1   3        0        6           0
# 5        2011-01-01       1   0     1   4        0        6           0
# ...             ...     ...  ..   ...  ..      ...      ...         ...
# 17375    2012-12-31       1   1    12  19        0        1           1
# 17376    2012-12-31       1   1    12  20        0        1           1
# 17377    2012-12-31       1   1    12  21        0        1           1
# 17378    2012-12-31       1   1    12  22        0        1           1
# 17379    2012-12-31       1   1    12  23        0        1           1
#
#          weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# instant
# ...

# %%
hourly_X = hourly_data.drop(columns=['cnt', 'casual', 'registered'])
hourly_y = hourly_data.cnt

# %%
hourly_X.corrwith(hourly_y)
# Out:
# season        0.178056
# yr            0.250495
# mnth          0.120638
# hr            0.394071
# holiday      -0.030927
# weekday       0.026900
# workingday    0.030284
# weathersit   -0.142426
# temp          0.404772
# atemp         0.400929
# hum          -0.322911
# windspeed     0.093234
# dtype: float64

# %%
hourly_X.corrwith(hourly_y).abs().plot.bar()
plt.show()
